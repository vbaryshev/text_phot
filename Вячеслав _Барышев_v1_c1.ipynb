# %% [markdown]
# <img src="http://s3.amazonaws.com/pix.iemoji.com/images/emoji/apple/ios-12/256/waving-hand.png" align=left width=44, heigth=44>
# <div class="alert alert-info">
# <b> Комментарий ревьюера</b>
#
#
# Привет! Давай знакомиться! Меня зовут Дмитрий Махортов, и я буду проверять твой проект. Сразу предлагаю общение на «ты» 🙂, но если тебе это не комфортно, то дай знать, и мы перейдем на «вы».
#
#
# Моя основная цель — не указать на совершенные тобою ошибки, а поделиться своим опытом и помочь тебе погрузиться в увлекательный мир работы с данными и вырасти в крепкого профи. Это отдаленная цель. А ближайшая - сделать твою работу еще лучше )).
#
#
#
# Расскажу как обычно проходит проверка:
# Бывают моменты, которые требуют пристального внимания. Комментарии по ним выделены <span style='background-color:#F7B3A4'> красным цветом </span> и обозначены значком 🛑. После их доработки проект будет принят.  🙂
#
# <span style='background-color:#B7EBA7'> Зеленым цветом </span> и значком ✅ отмечены удачные и элегантные решения, на которые можно опираться в будущих проектах. Или советы «со звездочкой», которые помогут тебе в будущем.
#
# <span style='background-color:#F9EDA6'>Жёлтым цветом </span> и значком ⚠️ выделено то, что в следующий раз можно сделать по-другому. Ты можешь учесть эти комментарии при выполнении будущих заданий или доработать проект сейчас (однако это не обязательно).
#
# Давай работать над проектом в диалоге: **если ты что-то меняешь в проекте по моим рекомендациям — пиши об этом**. Выбери для своих комментариев какой-то заметный цвет, так мне будет легче отследить изменения. Пожалуйста, **не перемещай, не изменяй и не удаляй мои комментарии**. Всё это поможет выполнить повторную проверку твоего проекта оперативнее.
# </div>

# %% [markdown]
# <div class="alert" style="background-color:#ead7f7;color:#8737bf">
#     <font size="3"><b>образец комментария студента</b></font>
#
# Можешь использовать этот комментарий. Просто удали этот текст и вместо него напиши свой 🙂
#
# </div>

# %% [markdown]
# <img src="https://upload.wikimedia.org/wikipedia/commons/thumb/8/81/Stop_sign.png/240px-Stop_sign.png" align=left width=35, heigth=35>
# <div class="alert alert-danger">
# К сожалению сейчас ты прислал проект который больше похож на черновик и делать ревью (особенно такого сложного прокта) в таком виде практически невозможно.
#
# В проекте я вижу только код. Структура минимальная, отсутствуют пояснения к выполняемым шагам, нет ни одного вывода.
#
# Очень прошу тебя к следующему  ревью привести проект в порядок. А именно.
#
#   - у проекта должны быть заголовок, введение
#   - в процессе работы над проектом нужно показывать читателю логику работы давая пояснения в маркдун ячейках
#   - не нужно делать большие ячейки. если в ячейке несколько операций - разбей её на две небольших, понятных
#   - проект должен быть разбит на небольшие логически обоснованные шаги, каждый шаг выполнен в отдельном разделе. в конце раздела нужно показать полученный  результат (что мы получили к данному этапу), а также написаны выводы (подведены итоги), что сделано в разделе. Например, после проведения исследовательского анализа нужно подробно расписать, что ты узнал про датасет.  После завершения предобработки (когда мы из нескольких датафреймов собираем один, с которым потом будем работать) нужно показать основную информацию об этом датафрейме (несколько строк + info).
#   - вот список разделов, которые я рекомендую выделить
#     - загрузка и первичный осмотр данных
#     - EDA - знакомство с загруженными данными. основной результат этапа - выводы + стратегия предобработки
#     - предобработка. основная цель этапа используя три датафрейма (экспертные оценки, крауд оценки, train_data) создать датафрейм "признаки-таргет", где признаки это пара изображение + описание, а таргет - это оценка соответствия, приведенная к шкале 0-1.
#     - чистка датасета от детских фото
#     - векторизация изображений
#     - векторизация текстов
#     - объединение векторов изображений и текстов с нашими данными
#     - получение выборок и обучение моделей
#     - тестирование
#     - итоговые выводы
#
#
#  --------------
#
#  Без этого я не смогу провести ревью проекта. Поэтому сейчая я только ограничусь наиболее яркими критичными ошибками.
#
# </div>

# %% [markdown]
# ### Поиск фотографий по описанию в фотохостинге «Со Смыслом» (“With Sense”)

# %% [markdown]
# Поиск фотографий по описанию в фотохостинге «Со Смыслом» (“With Sense”).
# Ваши пользователи размещают свои фотографии на хостинге и сопровождают их полным описанием: указывают место съёмок, модель камеры и т. д.
#
# Отличительная особенность сервиса — описание: его может предоставить не только тот, кто размещает фотографию, но и другие пользователи портала.
#
# Для демонстрационной версии нужно выбрать лучшую  модель, которая получит векторное представление изображения, векторное представление текста, а на выходе выдаст число от 0 до 1 — и покажет, насколько текст и картинка подходят друг другу.
#
# На основе лучшей модели можно будет собрать предварительную версию продукта, которую вы покажете руководителю компании.
#
# Описание данных
# В файле train_dataset.csv находится информация, необходимая для обучения: имя файла изображения, идентификатор описания и текст описания. Для одной картинки может быть доступно до 5 описаний. Идентификатор описания имеет формат <имя файла изображения>#<порядковый номер описания>.
# В папке train_images содержатся изображения для тренировки модели.
# В файле CrowdAnnotations.tsv  — данные по соответствию изображения и описания, полученные с помощью краудсорсинга. Номера колонок и соответствующий тип данных:
#
# Имя файла изображения.
#
# Идентификатор описания.
#
# Доля людей, подтвердивших, что описание соответствует изображению.
#
# Количество человек, подтвердивших, что описание соответствует изображению.
# Количество человек, подтвердивших, что описание не соответствует изображению.
# В файле ExpertAnnotations.tsv  — данные по соответствию изображения и описания, полученные в результате опроса экспертов.
#
# мера колонок и соответствующий тип данных:
# Имя файла изображения.
# Идентификатор описания.
# 3, 4, 5 — оценки трёх экспертов.
#
#
# Эксперты ставят оценки по шкале от 1 до 4, где 1 — изображение и запрос совершенно не соответствуют друг другу, 2 — запрос содержит элементы описания изображения, но в целом запрос тексту не соответствует, 3 — запрос и текст соответствуют с точностью до некоторых деталей, 4 — запрос и текст соответствуют полностью.
# В файле test_queries.csv находится информация, необходимая для тестирования: идентификатор запроса, текст запроса и релевантное изображение. Для одной картинки может быть доступно до 5 описаний. Идентификатор описания имеет формат <имя файла изображения>#<порядковый номер описания>.
# В папке test_images содержатся изображения для тестирования модели.

# %%
# !pip install --upgrade scikeras
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# ...
# WARNING: Ignoring invalid distribution -pencv-python (c:\users\пользователь\appdata\roaming\python\python39\site-packages)
# WARNING: Ignoring invalid distribution -pencv-python (c:\users\пользователь\appdata\roaming\python\python39\site-packages)
# WARNING: Ignoring invalid distribution -pencv-python (c:\users\пользователь\appdata\roaming\python\python39\site-packages)
# WARNING: Ignoring invalid distribution -pencv-python (c:\users\пользователь\appdata\roaming\python\python39\site-packages)
# WARNING: Ignoring invalid distribution -pencv-python (c:\users\пользователь\appdata\roaming\python\python39\site-packages)
# WARNING: Ignoring invalid distribution -pencv-python (c:\users\пользователь\appdata\roaming\python\python39\site-packages)

# %%
# !pip install scikeras
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# ...
# WARNING: Ignoring invalid distribution -pencv-python (c:\users\пользователь\appdata\roaming\python\python39\site-packages)
# WARNING: Ignoring invalid distribution -pencv-python (c:\users\пользователь\appdata\roaming\python\python39\site-packages)
# WARNING: Ignoring invalid distribution -pencv-python (c:\users\пользователь\appdata\roaming\python\python39\site-packages)
# WARNING: Ignoring invalid distribution -pencv-python (c:\users\пользователь\appdata\roaming\python\python39\site-packages)
# WARNING: Ignoring invalid distribution -pencv-python (c:\users\пользователь\appdata\roaming\python\python39\site-packages)
# WARNING: Ignoring invalid distribution -pencv-python (c:\users\пользователь\appdata\roaming\python\python39\site-packages)

# %%
import requests
import zipfile
import io
import os
import pandas as pd
import numpy as np
from pathlib import Path
import tensorflow as tf
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.model_selection import train_test_split, GroupShuffleSplit
from sklearn.linear_model import LinearRegression, Ridge, Lasso
from sklearn.metrics import mean_absolute_error
from keras.optimizers import Adam
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, Dropout
from tensorflow.keras.regularizers import l2
from tensorflow.keras.optimizers import RMSprop
from tensorflow.keras.callbacks import EarlyStopping
from tensorflow.keras.layers import BatchNormalization
import numpy as np
from sklearn.model_selection import train_test_split, RandomizedSearchCV
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, BatchNormalization, Dropout
from tensorflow.keras.callbacks import EarlyStopping
from sklearn.model_selection import GridSearchCV
from PIL import Image
from sklearn.metrics.pairwise import cosine_similarity
from transformers import BertTokenizer, BertModel
import torch
import torch.nn as nn
import torch.optim as optim
from torchvision import transforms
from torchvision.models import resnet50
from PIL import Image
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

# %% [markdown]
# ### Шаг 1. Загрузите данные и проведите исследовательский анализ данных

# %% [markdown]
# ***Чтение даных из директории***

# %%
def read_df(path: str) -> tuple:
    '''Читаем датафреймы из указанной директории'''
    
    # Проверка наличия файлов перед чтением
    path = Path(path)
    train_path = path / 'train_dataset.csv'
    crowd_path = path / 'CrowdAnnotations.tsv'
    expert_path = path / 'ExpertAnnotations.tsv'
    queries_path = path / 'test_queries.csv'
    images_path = path / 'test_images.csv'
    
    if not train_path.exists():
        raise FileNotFoundError(f"Файл {train_path} не найден.")
    if not crowd_path.exists():
        raise FileNotFoundError(f"Файл {crowd_path} не найден.")
    if not expert_path.exists():
        raise FileNotFoundError(f"Файл {expert_path} не найден.")
    if not queries_path.exists():
        raise FileNotFoundError(f"Файл {queries_path} не найден.")
    if not images_path.exists():
        raise FileNotFoundError(f"Файл {images_path} не найден.")
    
    # Чтение данных
    df_train = pd.read_csv(train_path)
    df_crowd = pd.read_csv(crowd_path, sep='\t', names=['image', 'query_id', 'share_pos', 'count_pos', 'count_neg'])
    df_expert = pd.read_csv(expert_path, sep='\t', names=['image', 'query_id', 'first', 'second', 'third'])
    df_queries = pd.read_csv(queries_path, index_col=[0], sep='|')
    df_images = pd.read_csv(images_path, sep='|')
    
    return df_train, df_crowd, df_expert, df_queries, df_images

# %% [markdown]
# ***Отображение изображений из тренировочного и тестового наборов данны***

# %%
def display_images(path: str, df_train: pd.DataFrame, df_queries: pd.DataFrame):
    '''Отображение изображений из тренировочного и тестового наборов данных'''
    
    samples_train = list(df_train['image'].sample(8))
    samples_test = list(df_queries['image'].sample(8))
    
    fig, axes = plt.subplots(4, 4, figsize=(10, 10))
    fig.tight_layout()
    
    for i in range(8):
        train_image_path = Path(path) / 'train_images' / samples_train[i]
        test_image_path = Path(path) / 'test_images' / samples_test[i]
        
        # Отображение тренировочных изображений
        ax = axes[i // 4, i % 4]
        image = Image.open(train_image_path)
        ax.imshow(image)
        ax.set_xticks([])
        ax.set_yticks([])
        
        # Отображение тестовых изображений
        ax = axes[(i // 4) + 2, i % 4]
        image = Image.open(test_image_path)
        ax.imshow(image)
        ax.set_xticks([])
        ax.set_yticks([])

# %%
# Использование функции
path_to_data = 'C:\\datasets\\image_search\\to_upload'
df_train, df_crowd, df_expert, df_queries, df_images = read_df(path_to_data)

# %%
# Вывод первых нескольких строк каждого DataFrame для проверки
print("Train Dataset:")
print(df_train.head())
print("\nCrowd Annotations:")
print(df_crowd.head())
print("\nExpert Annotations:")
print(df_expert.head())
print("\nTest Queries:")
print(df_queries.head())
print("\nTest Images:")
print(df_images.head())
# Out:
# Train Dataset:
#                        image                     query_id  \
# 0  1056338697_4f7d7ce270.jpg  2549968784_39bfbe44f9.jpg#2
# 1  1262583859_653f1469a9.jpg  2549968784_39bfbe44f9.jpg#2
# 2  2447284966_d6bbdb4b6e.jpg  2549968784_39bfbe44f9.jpg#2
# 3  2549968784_39bfbe44f9.jpg  2549968784_39bfbe44f9.jpg#2
# 4  2621415349_ef1a7e73be.jpg  2549968784_39bfbe44f9.jpg#2
#
#                                           query_text
# 0  A young child is wearing blue goggles and sitt...
# 1  A young child is wearing blue goggles and sitt...
# 2  A young child is wearing blue goggles and sitt...
# 3  A young child is wearing blue goggles and sitt...
# 4  A young child is wearing blue goggles and sitt...
#
# Crowd Annotations:
#                        image                     query_id  share_pos  \
# 0  1056338697_4f7d7ce270.jpg  1056338697_4f7d7ce270.jpg#2        1.0
# 1  1056338697_4f7d7ce270.jpg   114051287_dd85625a04.jpg#2        0.0
# ...

# %%
# Отображение изображений
display_images(path_to_data, df_train, df_queries)
plt.show()

# %% [markdown]
# <img src="https://upload.wikimedia.org/wikipedia/commons/b/ba/Warning_sign_4.0.png" align=left width=44, heigth=33>
# <div class="alert alert-warning">
#
#
# Прошу разделить длиную ячейку на несколько логичкских частей.</div>

# %% [markdown]
# <div class="alert" style="background-color:#ead7f7;color:#8737bf">
#     <font size="3"><b>образец комментария студента</b></font>
#
# Внесено
#
# </div>

# %%
display(df_train.head(), df_crowd.head(), df_expert.head(), df_queries.head(), df_images.head())
# Out:
#                        image                     query_id  \
# 0  1056338697_4f7d7ce270.jpg  2549968784_39bfbe44f9.jpg#2
# 1  1262583859_653f1469a9.jpg  2549968784_39bfbe44f9.jpg#2
# 2  2447284966_d6bbdb4b6e.jpg  2549968784_39bfbe44f9.jpg#2
# 3  2549968784_39bfbe44f9.jpg  2549968784_39bfbe44f9.jpg#2
# 4  2621415349_ef1a7e73be.jpg  2549968784_39bfbe44f9.jpg#2
#
#                                           query_text
# 0  A young child is wearing blue goggles and sitt...
# 1  A young child is wearing blue goggles and sitt...
# 2  A young child is wearing blue goggles and sitt...
# 3  A young child is wearing blue goggles and sitt...
# 4  A young child is wearing blue goggles and sitt...
#                        image                     query_id  share_pos  \
# 0  1056338697_4f7d7ce270.jpg  1056338697_4f7d7ce270.jpg#2        1.0
# 1  1056338697_4f7d7ce270.jpg   114051287_dd85625a04.jpg#2        0.0
# 2  1056338697_4f7d7ce270.jpg  1427391496_ea512cbe7f.jpg#2        0.0
# ...

# %% [markdown]
# ### 1. df_train

# %%
display(df_train.head())
# Out:
#                        image                     query_id  \
# 0  1056338697_4f7d7ce270.jpg  2549968784_39bfbe44f9.jpg#2
# 1  1262583859_653f1469a9.jpg  2549968784_39bfbe44f9.jpg#2
# 2  2447284966_d6bbdb4b6e.jpg  2549968784_39bfbe44f9.jpg#2
# 3  2549968784_39bfbe44f9.jpg  2549968784_39bfbe44f9.jpg#2
# 4  2621415349_ef1a7e73be.jpg  2549968784_39bfbe44f9.jpg#2
#
#                                           query_text
# 0  A young child is wearing blue goggles and sitt...
# 1  A young child is wearing blue goggles and sitt...
# 2  A young child is wearing blue goggles and sitt...
# 3  A young child is wearing blue goggles and sitt...
# 4  A young child is wearing blue goggles and sitt...

# %%
df_train.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5822 entries, 0 to 5821
# Data columns (total 3 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   image       5822 non-null   object
#  1   query_id    5822 non-null   object
#  2   query_text  5822 non-null   object
# dtypes: object(3)
# memory usage: 136.6+ KB

# %%
# Подсчет уникальных значений в каждом столбце
unique_counts = df_train.nunique()

# Построение графика
plt.figure(figsize=(10, 6))
sns.barplot(x=unique_counts.index, y=unique_counts.values)
plt.xlabel('Столбец')
plt.ylabel('Количество уникальных значений')
plt.title('Количество уникальных значений в столбце')
plt.show()

# %%
# Вычисление длины текста в столбце query_text
df_train['text_length'] = df_train['query_text'].apply(len)

# Построение графика распределения длины текста
plt.figure(figsize=(10, 6))
sns.histplot(df_train['text_length'], bins=20, kde=True)
plt.xlabel('Длина текста запроса')
plt.ylabel('Частота')
plt.title('Распределение длины текста запроса')
plt.show()

# %%
# Удаление столбца text_length
df_train.drop(columns=['text_length'], inplace=True)

# %%
df_train.describe()
# Out:
#                             image                     query_id  \
# count                        5822                         5822
# unique                       1000                          977
# top     3364151356_eecd07a23e.jpg  2600867924_cd502fc911.jpg#2
# freq                           10                           34
#
#                                                query_text
# count                                                5822
# unique                                                977
# top     Two dogs , one brown and white and one black a...
# freq                                                   34

# %% [markdown]
# #### Вывод:
# df_train содержит обучающие данные. Основные столбцы могут включать признаки (features) и целевые значения (targets). Анализ структуры данных поможет понять, какие типы данных присутствуют и есть ли пропущенные значения.
#
#
# Набор данных состоит из 5822 записей с значительным количеством повторений, особенно в идентификаторах запросов и текстах запросов. Наиболее частое изображение встречается 10 раз, в то время как наиболее частые идентификатор запроса и текст запроса встречаются по 34 раза каждый. Это указывает на то, что определенные изображения и запросы многократно используются в наборе данных

# %% [markdown]
# ### 2. df_crowd

# %%
display(df_crowd.head())
# Out:
#                        image                     query_id  share_pos  \
# 0  1056338697_4f7d7ce270.jpg  1056338697_4f7d7ce270.jpg#2        1.0
# 1  1056338697_4f7d7ce270.jpg   114051287_dd85625a04.jpg#2        0.0
# 2  1056338697_4f7d7ce270.jpg  1427391496_ea512cbe7f.jpg#2        0.0
# 3  1056338697_4f7d7ce270.jpg  2073964624_52da3a0fc4.jpg#2        0.0
# 4  1056338697_4f7d7ce270.jpg  2083434441_a93bc6306b.jpg#2        0.0
#
#    count_pos  count_neg
# 0          3          0
# 1          0          3
# 2          0          3
# 3          0          3
# 4          0          3

# %%
df_crowd.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 47830 entries, 0 to 47829
# Data columns (total 5 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   image      47830 non-null  object
#  1   query_id   47830 non-null  object
#  2   share_pos  47830 non-null  float64
#  3   count_pos  47830 non-null  int64
#  4   count_neg  47830 non-null  int64
# dtypes: float64(1), int64(2), object(2)
# memory usage: 1.8+ MB

# %%
# Подсчет уникальных значений в каждом столбце
unique_counts = df_crowd.nunique()

# Построение графика
plt.figure(figsize=(10, 6))
sns.barplot(x=unique_counts.index, y=unique_counts.values)
plt.xlabel('Столбец')
plt.ylabel('Количество уникальных значений')
plt.title('Количество уникальных значений в столбце')
plt.show()

# %% [markdown]
# 1. Гистограмма распределения значений в столбце share_pos.
# 2. Гистограмма распределения значений в столбце count_pos.
# 3. Гистограмма распределения значений в столбце count_neg.
# 4. Диаграмму рассеяния для анализа взаимосвязи между count_pos и count_neg.
# 5. Диаграмму рассеяния для анализа взаимосвязи между share_pos и count_pos.

# %%
df_crowd.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 47830 entries, 0 to 47829
# Data columns (total 5 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   image      47830 non-null  object
#  1   query_id   47830 non-null  object
#  2   share_pos  47830 non-null  float64
#  3   count_pos  47830 non-null  int64
#  4   count_neg  47830 non-null  int64
# dtypes: float64(1), int64(2), object(2)
# memory usage: 1.8+ MB

# %%
df_crowd.describe()
# Out:
#           share_pos     count_pos     count_neg
# count  47830.000000  47830.000000  47830.000000
# mean       0.068786      0.208488      2.820155
# std        0.207532      0.628898      0.656676
# min        0.000000      0.000000      0.000000
# 25%        0.000000      0.000000      3.000000
# 50%        0.000000      0.000000      3.000000
# 75%        0.000000      0.000000      3.000000
# max        1.000000      5.000000      6.000000

# %%
# Настройка стиля seaborn
sns.set(style="whitegrid")

# Создание фигуры с несколькими подграфиками
fig, axes = plt.subplots(2, 2, figsize=(15, 10))

# Гистограмма для share_pos
sns.histplot(df_crowd['share_pos'], bins=30, kde=True, ax=axes[0, 0])
axes[0, 0].set_title('Распределение share_pos')
axes[0, 0].set_xlabel('share_pos')
axes[0, 0].set_ylabel('Частота')

# Гистограмма для count_pos
sns.histplot(df_crowd['count_pos'], bins=30, kde=True, ax=axes[0, 1])
axes[0, 1].set_title('Распределение count_pos')
axes[0, 1].set_xlabel('count_pos')
axes[0, 1].set_ylabel('Частота')

# Гистограмма для count_neg
sns.histplot(df_crowd['count_neg'], bins=30, kde=True, ax=axes[1, 0])
axes[1, 0].set_title('Распределение count_neg')
axes[1, 0].set_xlabel('count_neg')
axes[1, 0].set_ylabel('Частота')

# Диаграмма рассеяния для count_pos против count_neg
sns.scatterplot(x='count_pos', y='count_neg', data=df_crowd, ax=axes[1, 1])
axes[1, 1].set_title('Зависимость count_pos от count_neg')
axes[1, 1].set_xlabel('count_pos')
axes[1, 1].set_ylabel('count_neg')

plt.tight_layout()
plt.show()

# %%
# Создание отдельных коробчатых диаграмм
fig, axes = plt.subplots(1, 3, figsize=(18, 6))

# Коробчатая диаграмма для share_pos
sns.boxplot(y=df_crowd['share_pos'], ax=axes[0])
axes[0].set_title('Коробчатая диаграмма share_pos')

# Коробчатая диаграмма для count_pos
sns.boxplot(y=df_crowd['count_pos'], ax=axes[1])
axes[1].set_title('Коробчатая диаграмма count_pos')

# Коробчатая диаграмма для count_neg
sns.boxplot(y=df_crowd['count_neg'], ax=axes[2])
axes[2].set_title('Коробчатая диаграмма count_neg')

plt.tight_layout()
plt.show()

# %% [markdown]
# #### Вывод:
# df_crowd может содержать данные, собранные от множества пользователей или аннотаторов. Это может быть полезно для задач, связанных с краудсорсингом. Анализ структуры данных покажет, насколько данные разнообразны и качественны.
#
# 1. **Общая структура данных**:
#    - DataFrame содержит 47,830 строк и 5 столбцов.
#    - Столбцы включают:
#      - image (тип данных: object) — вероятно, содержит имена файлов изображений или ссылки на них.
#      - query_id (тип данных: object) — уникальные идентификаторы запросов.
#      - share_pos (тип данных: float64) — доля положительных отзывов.
#      - count_pos (тип данных: int64) — количество положительных отзывов.
#      - count_neg (тип данных: int64) — количество отрицательных отзывов.
#
# 2. **Отсутствие пропущенных значений**:
#    - Все столбцы содержат 47,830 непустых значений, что указывает на отсутствие пропущенных данных.
#
# 3. **Статистическое описание числовых столбцов**:
#    - **share_pos**:
#      - Среднее значение составляет примерно 0.0688, что указывает на то, что доля положительных отзывов в среднем составляет около 6.88%.
#      - Стандартное отклонение равно 0.2075, что говорит о значительном разбросе значений.
#      - Минимальное значение равно 0, а максимальное — 1, что логично для доли.
#    - **count_pos**:
#      - Среднее значение равно примерно 0.2085, что указывает на низкое среднее количество положительных отзывов.
#      - Стандартное отклонение составляет 0.6289, что указывает на значительный разброс значений.
#      - Минимальное значение равно 0, а максимальное — 5.
#    - **count_neg**:
#      - Среднее значение равно примерно 2.8202, что указывает на высокое среднее количество отрицательных отзывов.
#      - Стандартное отклонение составляет 0.6567, что говорит о меньшем разбросе значений по сравнению с count_pos.
#      - Минимальное значение равно 0, а максимальное — 6.
#
# 4. **Распределение значений**:
#    - Значения share_pos, count_pos, и count_neg имеют значительное количество нулевых значений, особенно это заметно по медианным значениям (50-й перцентиль), которые равны нулю для share_pos и count_pos.
#    - Верхние квартильные значения (75-й перцентиль) для count_neg равны 3, что также указывает на высокую частоту отрицательных отзывов.
#
# ### Заключеие:
# - Данные показывают, что изображения в среднем получают гораздо больше отрицательных отзывов по сравнению с положительными.
# - Значительное количество нулевых значений в столбцах share_pos и count_pos может указывать на то, что многие изображения не получают положительных отзывов вообще.
# - Высокое среднее значение и относительно низкое стандартное отклонение для count_neg указывают на то, что большинство изображений получают отрицательные отзывы.

# %% [markdown]
# ### 3. df_expert

# %%
display(df_expert.head())
# Out:
#                        image                     query_id  first  second  \
# 0  1056338697_4f7d7ce270.jpg  2549968784_39bfbe44f9.jpg#2      1       1
# 1  1056338697_4f7d7ce270.jpg  2718495608_d8533e3ac5.jpg#2      1       1
# 2  1056338697_4f7d7ce270.jpg  3181701312_70a379ab6e.jpg#2      1       1
# 3  1056338697_4f7d7ce270.jpg  3207358897_bfa61fa3c6.jpg#2      1       2
# 4  1056338697_4f7d7ce270.jpg  3286822339_5535af6b93.jpg#2      1       1
#
#    third
# 0      1
# 1      2
# 2      2
# 3      2
# 4      2

# %%
df_expert.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5822 entries, 0 to 5821
# Data columns (total 5 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   image     5822 non-null   object
#  1   query_id  5822 non-null   object
#  2   first     5822 non-null   int64
#  3   second    5822 non-null   int64
#  4   third     5822 non-null   int64
# dtypes: int64(3), object(2)
# memory usage: 227.5+ KB

# %%
df_expert.describe()
# Out:
#              first       second        third
# count  5822.000000  5822.000000  5822.000000
# mean      1.436620     1.624356     1.881999
# std       0.787084     0.856222     0.904087
# min       1.000000     1.000000     1.000000
# 25%       1.000000     1.000000     1.000000
# 50%       1.000000     1.000000     2.000000
# 75%       2.000000     2.000000     2.000000
# max       4.000000     4.000000     4.000000

# %%
# Подсчет уникальных значений в каждом столбце
unique_counts = df_expert.nunique()

# Построение графика
plt.figure(figsize=(10, 6))
sns.barplot(x=unique_counts.index, y=unique_counts.values)
plt.xlabel('Столбец')
plt.ylabel('Количество уникальных значений')
plt.title('Количество уникальных значений в столбце')
plt.show()

# %%
# Построим гистограммы для столбцов first, second и third
fig, axes = plt.subplots(1, 3, figsize=(18, 5))

sns.histplot(df_expert['first'], bins=range(1, 6), kde=False, ax=axes[0])
axes[0].set_title('Распределение значений в столбце "first"')
axes[0].set_xlabel('Значение')
axes[0].set_ylabel('Частота')

sns.histplot(df_expert['second'], bins=range(1, 6), kde=False, ax=axes[1])
axes[1].set_title('Распределение значений в столбце "second"')
axes[1].set_xlabel('Значение')
axes[1].set_ylabel('Частота')

sns.histplot(df_expert['third'], bins=range(1, 6), kde=False, ax=axes[2])
axes[2].set_title('Распределение значений в столбце "third"')
axes[2].set_xlabel('Значение')
axes[2].set_ylabel('Частота')

plt.tight_layout()
plt.show()

# %% [markdown]
# #### Вывод:
# df_expert вероятно содержит данные, аннотированные экспертами. Эти данные могут быть более точными и надежными по сравнению с данными из df_crowd. Анализ структуры данных поможет понять, какие особенности и метки присутствуют.

# %% [markdown]
# 1. **Распределение значений в столбце "first"**:
#    - Среднее значение составляет примерно 1.44.
#    - Большинство значений находятся в диапазоне от 1 до 2.
#    - Максимальное значение равно 4.
#
# 2. **Распределение значений в столбце "second"**:
#    - Среднее значение составляет примерно 1.62.
#    - Большинство значений также находятся в диапазоне от 1 до 2.
#    - Максимальное значение равно 4.
#
# 3. **Распределение значений в столбце "third"**:
#    - Среднее значение составляет примерно 1.88.
#    - Значения более равномерно распределены между 1 и 2 по сравнению с первыми двумя столбцами.
#    - Максимальное значение равно 4.
#
# Эти распределения показывают, что большинство значений в каждом из столбцов находится в нижней части диапазона (от 1 до 2), с меньшим количеством значений, достигающих верхних границ (3 и 4).

# %% [markdown]
# ### 4. df_queries

# %%
display(df_queries.head())
# Out:
#                       query_id  \
# 0  1177994172_10d143cb8d.jpg#0
# 1  1177994172_10d143cb8d.jpg#1
# 2  1177994172_10d143cb8d.jpg#2
# 3  1177994172_10d143cb8d.jpg#3
# 4  1177994172_10d143cb8d.jpg#4
#
#                                           query_text  \
# 0  Two blonde boys , one in a camouflage shirt an...
# 1  Two boys are squirting water guns at each other .
# 2            Two boys spraying each other with water
# 3  Two children wearing jeans squirt water at eac...
# 4  Two young boys are squirting water at each oth...
#
#                        image
# 0  1177994172_10d143cb8d.jpg
# 1  1177994172_10d143cb8d.jpg
# 2  1177994172_10d143cb8d.jpg
# 3  1177994172_10d143cb8d.jpg
# 4  1177994172_10d143cb8d.jpg

# %%
df_queries.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 500 entries, 0 to 499
# Data columns (total 3 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   query_id    500 non-null    object
#  1   query_text  500 non-null    object
#  2   image       500 non-null    object
# dtypes: object(3)
# memory usage: 15.6+ KB

# %%
df_queries.describe()
# Out:
#                            query_id  \
# count                           500
# unique                          500
# top     1177994172_10d143cb8d.jpg#0
# freq                              1
#
#                                                query_text  \
# count                                                 500
# unique                                                500
# top     Two blonde boys , one in a camouflage shirt an...
# freq                                                    1
#
#                             image
# count                         500
# unique                        100
# top     1177994172_10d143cb8d.jpg
# freq                            5

# %%
# Подсчет уникальных значений в каждом столбце
unique_counts = df_queries.nunique()

# Построение графика
plt.figure(figsize=(10, 6))
sns.barplot(x=unique_counts.index, y=unique_counts.values)
plt.xlabel('Столбец')
plt.ylabel('Количество уникальных значений')
plt.title('Количество уникальных значений в столбце')
plt.show()

# %%
# 1. Распределение длины текста запросов
df_queries['query_length'] = df_queries['query_text'].apply(len)
plt.figure(figsize=(10, 6))
sns.histplot(df_queries['query_length'], bins=30, kde=True)
plt.title('Распределение длины текста запросов')
plt.xlabel('Длина текста запроса')
plt.ylabel('Частота')
plt.show()

# %% [markdown]
# #### Вывод:
# df_queries вероятно содержит информацию о запросах, которые могут быть использованы для поиска или фильтрации данных. Анализ структуры данных поможет определить, какие запросы и параметры чаще всего используются.
#
# 1. **Распределение длины текста запросов:**
#    - Гистограмма показывает, как распределены длины текстов запросов. Это может помочь понять, есть ли типичная длина запроса и есть ли выбросы.
#
# 2. **Частотный анализ слов в запросах:**
#    - Столбчатая диаграмма показывает самые частые слова в текстах запросов. Это может помочь выявить ключевые темы и интересы пользователей.
#
# 3. **Распределение количества уникальных изображений:**
#    - Гистограмма показывает, как часто каждое изображение упоминается в запросах. Это может помочь понять, есть ли изображения, которые значительно более популярны среди пользователей.

# %% [markdown]
# ### 5. df_images

# %%
display(df_images.head())
# Out:
#                        image
# 0  3356748019_2251399314.jpg
# 1  2887171449_f54a2b9f39.jpg
# 2  3089107423_81a24eaf18.jpg
# 3  1429546659_44cb09cbe2.jpg
# 4  1177994172_10d143cb8d.jpg

# %%
df_images.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 100 entries, 0 to 99
# Data columns (total 1 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   image   100 non-null    object
# dtypes: object(1)
# memory usage: 928.0+ bytes

# %%
df_images.describe()
# Out:
#                             image
# count                         100
# unique                        100
# top     3356748019_2251399314.jpg
# freq                            1

# %%
# Подсчет уникальных значений в каждом столбце
unique_counts = df_images.nunique()

# Построение графика
plt.figure(figsize=(10, 6))
sns.barplot(x=unique_counts.index, y=unique_counts.values)
plt.xlabel('Столбец')
plt.ylabel('Количество уникальных значений')
plt.title('Количество уникальных значений в столбце')
plt.show()

# %% [markdown]
# df_images содержит информацию об изображениях, возможно, пути к файлам или метаданные изображений. Анализ структуры данных поможет понять, как изображения организованы и какие дополнительные данные присутствуют.
#
# 1. **Общая информация о DataFrame**:
#    - DataFrame содержит 100 строк и 1 столбец.
#    - Столбец называется image.
#    - Все 100 значений в столбце image не содержат пропусков (non-null).
#    - Тип данных в столбце image — object, что обычно означает, что значения представляют собой строки.
#
# 2. **Описание данных в столбце image**:
#    - Количество уникальных значений (unique) в столбце image равно 100, что означает, что все значения в этом столбце уникальны.
#    - Наиболее часто встречающееся значение (top) — 3356748019_2251399314.jpg, но частота его появления (freq) равна 1. Это подтверждает, что все значения уникальны.
#
# 3. **Использование памяти**:
#    - DataFrame использует приблизительно 928.0 байт памяти.
#
# ### Выводы:
# 1. **Уникальность данных**: Все изображения в DataFrame уникальны, так как количество строк совпадает с количеством уникальных значений в столбце image.
# 2. **Отсутствие пропусков**: В столбце image нет пропущенных значений, что упрощает дальнейшую работу с этими данными.
# 3. **Тип данных**: Значения в столбце image являются строками, что логично для хранения путей или имен файлов изображений.

# %% [markdown]
# <img src="https://upload.wikimedia.org/wikipedia/commons/b/ba/Warning_sign_4.0.png" align=left width=44, heigth=33>
# <div class="alert alert-warning">
# В этой и двух следующих ячейках ты пытаешься исследовать все датфафреймы одновременно. Давай поймем, зачем ты это делаешь
#
#  - потому что ревьюеры требуют знакомство с данными, нужно вывести
#  - чтобы читателю и автору проекта было понятно, с какими данными мы работаем, появилось погруженность в датасет
#
# если цель первая - то ОК, я оставил желтый комментарий и мы можем идти дальше. Но если ты хочешь все-таки познакомить читателя с датасетом, то советую идти следующим путем
#
#  - для каждого датафрейма создать свой подраздел (выделив его подзаголовком соответствующего уровня)
#  - в этом подразделе показать основную информацию и тут же написать  небольшой вывод
#
#
# Человек в состояни удновременно держать в уме только 5-8 объектов. Пытаясь одновременно исследовать 5 загруженных таблиц ты создаешь гораздо больше сущностей (выводишь результаты выполнения более 20 команд), что делает чтение твоего кода исследования невозмжоным.
#
# К тому же это накладывается на то, что в следующих двух ячейках ты используешь print для печати датафреймов, что делает их тяжелочитаемыми.
# </div>

# %% [markdown]
# <div class="alert" style="background-color:#ead7f7;color:#8737bf">
#     <font size="3"><b>образец комментария студента</b></font>
#
# Внесено
#
# </div>

# %%
# Функция для отображения общей информации о каждом DataFrame
def display_info(df_list, names):
    for df, name in zip(df_list, names):
        print(f"\n{name} Информация о наборе данных:")
        print(df.info())
        print("\nMissing values:")
        print(df.isnull().sum())
        print("\nHead of the dataset:")
        print(df.head())
        print("\n")

# Список DataFrame'ов и их имена
df_list = [df_train, df_crowd, df_expert, df_queries, df_images]
names = ['Train', 'Crowd Annotations', 'Expert Annotations', 'Test Queries', 'Test Images']

# Отображение информации
display_info(df_list, names)
# Out:
# Train Информация о наборе данных:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5822 entries, 0 to 5821
# Data columns (total 3 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   image       5822 non-null   object
#  1   query_id    5822 non-null   object
#  2   query_text  5822 non-null   object
# dtypes: object(3)
# memory usage: 136.6+ KB
# None
#
# Missing values:
# image         0
# query_id      0
# query_text    0
# dtype: int64
#
# Head of the dataset:
#                        image                     query_id  \
# 0  1056338697_4f7d7ce270.jpg  2549968784_39bfbe44f9.jpg#2
# 1  1262583859_653f1469a9.jpg  2549968784_39bfbe44f9.jpg#2
# 2  2447284966_d6bbdb4b6e.jpg  2549968784_39bfbe44f9.jpg#2
# 3  2549968784_39bfbe44f9.jpg  2549968784_39bfbe44f9.jpg#2
# 4  2621415349_ef1a7e73be.jpg  2549968784_39bfbe44f9.jpg#2
#
#                                           query_text
# 0  A young child is wearing blue goggles and sitt...
# ...

# %%
# Функция для отображения общей информации о наборах данных
def display_info(df_list, names):
    for df, name in zip(df_list, names):
        print(f"\n{name} Информация о наборе данных:")
        print(df.info())
        print("\nMissing values:")
        print(df.isnull().sum())
        print("\nHead of the dataset:")
        print(df.head())
        print("\n")

# %%
# Список DataFrame'ов и их имена
df_list = [df_train, df_crowd, df_expert, df_queries, df_images]
names = ['Train', 'Crowd Annotations', 'Expert Annotations', 'Test Queries', 'Test Images']

# %%
# Отображение информации
display_info(df_list, names)
# Out:
# Train Информация о наборе данных:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5822 entries, 0 to 5821
# Data columns (total 3 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   image       5822 non-null   object
#  1   query_id    5822 non-null   object
#  2   query_text  5822 non-null   object
# dtypes: object(3)
# memory usage: 136.6+ KB
# None
#
# Missing values:
# image         0
# query_id      0
# query_text    0
# dtype: int64
#
# Head of the dataset:
#                        image                     query_id  \
# 0  1056338697_4f7d7ce270.jpg  2549968784_39bfbe44f9.jpg#2
# 1  1262583859_653f1469a9.jpg  2549968784_39bfbe44f9.jpg#2
# 2  2447284966_d6bbdb4b6e.jpg  2549968784_39bfbe44f9.jpg#2
# 3  2549968784_39bfbe44f9.jpg  2549968784_39bfbe44f9.jpg#2
# 4  2621415349_ef1a7e73be.jpg  2549968784_39bfbe44f9.jpg#2
#
#                                           query_text
# 0  A young child is wearing blue goggles and sitt...
# ...

# %%
# Проверка наличия данных в каждом DataFrame
df_list = [df_train, df_crowd, df_expert, df_queries, df_images]
names = ['Train', 'Crowd Annotations', 'Expert Annotations', 'Test Queries', 'Test Images']

for df, name in zip(df_list, names):
    print(f"{name} dataset shape: {df.shape}")
# Out:
# Train dataset shape: (5822, 3)
# Crowd Annotations dataset shape: (47830, 5)
# Expert Annotations dataset shape: (5822, 5)
# Test Queries dataset shape: (500, 4)
# Test Images dataset shape: (100, 1)

# %%
# Проверка на наличие пустых строк и колонок
for df, name in zip(df_list, names):
    print(f"{name} dataset:")
    print(df.isnull().sum())
    print()
# Out:
# Train dataset:
# image         0
# query_id      0
# query_text    0
# dtype: int64
#
# Crowd Annotations dataset:
# image        0
# query_id     0
# share_pos    0
# count_pos    0
# count_neg    0
# dtype: int64
#
# Expert Annotations dataset:
# image       0
# query_id    0
# first       0
# second      0
# third       0
# dtype: int64
#
# Test Queries dataset:
# query_id        0
# query_text      0
# image           0
# query_length    0
# dtype: int64
#
# Test Images dataset:
# image    0
# dtype: int64

# %%
# Проверка типов данных
for df, name in zip(df_list, names):
    print(f"{name} dataset types:")
    print(df.dtypes)
    print()
# Out:
# Train dataset types:
# image         object
# query_id      object
# query_text    object
# dtype: object
#
# Crowd Annotations dataset types:
# image         object
# query_id      object
# share_pos    float64
# count_pos      int64
# count_neg      int64
# dtype: object
#
# Expert Annotations dataset types:
# image       object
# query_id    object
# first        int64
# second       int64
# third        int64
# dtype: object
#
# Test Queries dataset types:
# query_id        object
# query_text      object
# image           object
# query_length     int64
# dtype: object
#
# Test Images dataset types:
# image    object
# dtype: object

# %%
# Проверка на дублирующиеся строки
for df, name in zip(df_list, names):
    duplicates = df.duplicated().sum()
    print(f"{name} набор данных имеет{duplicates} дубликатов.")
    print()
# Out:
# Train набор данных имеет0 дубликатов.
#
# Crowd Annotations набор данных имеет0 дубликатов.
#
# Expert Annotations набор данных имеет0 дубликатов.
#
# Test Queries набор данных имеет0 дубликатов.
#
# Test Images набор данных имеет0 дубликатов.

# %%
# Проверка наличия столбца 'share_pos' в df_crowd
if 'share_pos' in df_crowd.columns:
    # Пример визуализации распределения значений в Crowd Annotations
    plt.figure(figsize=(10, 6))
    sns.histplot(df_crowd['share_pos'], bins=30, kde=True)
    plt.title('Распределение share_pos в аннотациях Crowd')
    plt.xlabel('общий доступ')
    plt.ylabel('Частота')
    plt.show()
else:
    print("Столбец 'share_pos' не существует в df_crowd")

# %%
# Проверка наличия числовых данных в df_train
if not df_train.select_dtypes(include=[np.number]).empty:
    # Пример визуализации корреляционной матрицы в Train Dataset
    plt.figure(figsize=(12, 10))
    sns.heatmap(df_train.corr(), annot=True, fmt='.2f', cmap='coolwarm', linewidths=0.5)
    plt.title('Корреляционная матрица набора данных о поездах')
    plt.show()
else:
    print("df_train не содержит числовых данных для корреляционной матрицы")
# Out:
# df_train не содержит числовых данных для корреляционной матрицы

# %% [markdown]
# <img src="https://upload.wikimedia.org/wikipedia/commons/b/ba/Warning_sign_4.0.png" align=left width=44, heigth=33>
# <div class="alert alert-warning">
#
#
# Все импорты стоит перенести в начало проекта</div>

# %% [markdown]
# <div class="alert" style="background-color:#ead7f7;color:#8737bf">
#     <font size="3"><b>образец комментария студента</b></font>
#
# Внесено
#
# </div>

# %%
try:
    if 'image' in df_train.columns:
        unique_train_images = len(df_train['image'].unique())
        print('Количество уникальных фото на обучающем наборе данных:', unique_train_images)
    else:
        print("Столбец 'image' отсутствует в df_train")

    if 'image' in df_queries.columns:
        unique_test_images = len(df_queries['image'].unique())
        print('Количество уникальных фото в тестовом наборе данных:', unique_test_images)
    else:
        print("Столбец 'image' отсутствует в df_queries")
except Exception as e:
    print(f"Произошла ошибка: {e}")
# Out:
# Количество уникальных фото на обучающем наборе данных: 1000
# Количество уникальных фото в тестовом наборе данных: 100

# %%
try:
    # Проверка наличия необходимых столбцов
    if not df_expert.empty:
        unique_expert_combinations = df_expert.drop_duplicates().shape[0]
        print('Количество уникальных сочетаний фото-текст оцененных экспертами:', unique_expert_combinations)
    else:
        print("Набор данных df_expert пустой или не содержит данных")

    if not df_crowd.empty:
        unique_crowd_combinations = df_crowd.drop_duplicates().shape[0]
        print('Количество уникальных сочетаний фото-текст оцененных людьми:', unique_crowd_combinations)
    else:
        print("Набор данны df_crowd пустой или не содержит данных")
except Exception as e:
    print(f"Произошла ошибка: {e}")
# Out:
# Количество уникальных сочетаний фото-текст оцененных экспертами: 5822
# Количество уникальных сочетаний фото-текст оцененных людьми: 47830

# %%
df_expert.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5822 entries, 0 to 5821
# Data columns (total 5 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   image     5822 non-null   object
#  1   query_id  5822 non-null   object
#  2   first     5822 non-null   int64
#  3   second    5822 non-null   int64
#  4   third     5822 non-null   int64
# dtypes: int64(3), object(2)
# memory usage: 227.5+ KB

# %% [markdown]
# <img src="https://upload.wikimedia.org/wikipedia/commons/thumb/8/81/Stop_sign.png/240px-Stop_sign.png" align=left width=35, heigth=35>
# <div class="alert alert-danger">
# Пожалуйста напиши выводы</div>

# %% [markdown]
# <img src="https://upload.wikimedia.org/wikipedia/commons/b/ba/Warning_sign_4.0.png" align=left width=44, heigth=33>
# <div class="alert alert-warning">
# Чтобы в дальнейшем не было проблем с предобработкой стоит определить стратегию и следуя этой стратегии используя три таблички (крауд и экспертны оценки, а также `Train dataset`) создать ОДИН датафрейм в котором будут поля
#
#   - image
#   - query_id
#   - query_text
#   - итоговая оценка, как-то полученная с использованием экспертных и (возможно) крауд
# </div>

# %% [markdown]
# <div class="alert" style="background-color:#ead7f7;color:#8737bf">
#     <font size="3"><b>образец комментария студента</b></font>
#
# Внесено
#
# </div>

# %% [markdown]
# ### Шаг 2. Подготовьте данные к обучению модели

# %% [markdown]
# 1. Создайте список слов которые, по вашему мнению, могут попадать под юридические ограничения.
#
# 2. Исключите из обучающего датасета пары, которые, исходя из подготовленного вами списка слов, могут попадать под юридические ограничения.
#
# 3. Сделайте векторизацию текстового описания одним из следующих методов:
#
# - TF-IDF;
#
# - BERT;
#
# - word2vec.
#
# 4. Сделайте векторизацию изображений с использованием модели ResNet50 из библиотеки Keras или PyTorch.
#
# 5. Дайте описание получившихся пар векторов с точки зрения их размерностей.

# %%
# Проверка наличия столбца 'query_text'
print(df_train.columns)
# Out:
# Index(['image', 'query_id', 'query_text'], dtype='object')

# %%
column_name = 'query_text'

restricted_words = [
    'weapon', 'drugs', 'violence', 'terrorism','child', 'children', 'kid', 'kids', 
    'pornography', 'extremism', 'murder', 'suicide', 'baby', 'babies', 'infant', 'toddler'
]

# %% [markdown]
# <img src="https://upload.wikimedia.org/wikipedia/commons/thumb/8/81/Stop_sign.png/240px-Stop_sign.png" align=left width=35, heigth=35>
# <div class="alert alert-danger">
# В задании сказано, что нужно очистить датасет от изображений с детьми. Использованные тобой слова никак не связаны с детской тематикой.
#
# --------------------
#
# Более того, ты удаляешь комментарии, в которых есть запрещенные слова. Но наша задача убрать изображения, содержащие детей. Есть два способа сделать это:
#
#  - Определить список "плохих" изображений, как изображения удовлетворяющие условиям:
#     - Комментарий содержит плохие  слова (слова описывающие детей)
#     - <b>Оценка соответствия комментария и изображения выше порога.</b>
#  - Удалить из нашего датасета все пары "изображение/описание" с плохими изображениями.
#
#
# И второй, очень красивый способ. Он основан на том, что `query_id` содержит в с себе имя изображения, для которого он был написан (такая пасхалочка от авторов датасета).
#
#  - Определить список плохих комментариев
#  - У `query_id`  плохих комментариев отрезать два последних символа и получим список плохих изображений.
#
#
#
#
# </div>

# %% [markdown]
# <div class="alert" style="background-color:#ead7f7;color:#8737bf">
#     <font size="3"><b>образец комментария студента</b></font>
#
# Внесено
#
# </div>

# %%
def filter_child_images(df_train: pd.DataFrame, restricted_words: list, column_name: str) -> pd.DataFrame:
    '''Исключение запрещенных слов из набора данных.'''
    # Создаем паттерн для поиска слов
    pattern = '|'.join(restricted_words)
    
    # Определяем плохие комментарии
    bad_comments = df_train[df_train[column_name].str.contains(pattern, case=False, na=False)]
    
    # Извлекаем query_id плохих комментариев и удаляем последние два символа
    bad_image_ids = bad_comments['query_id'].str[:-2]
    
    # Фильтруем датасет, исключая изображения с плохими идентификаторами
    filtered_df = df_train[~df_train['image'].isin(bad_image_ids)]
    
    return filtered_df

# Применяем функцию к df_train
df_train_filtered  = filter_child_images(df_train, restricted_words, 'query_text')

# Проверяем результат
print(df_train_filtered)
# Out:
#                           image                     query_id  \
# 0     1056338697_4f7d7ce270.jpg  2549968784_39bfbe44f9.jpg#2
# 1     1262583859_653f1469a9.jpg  2549968784_39bfbe44f9.jpg#2
# 2     2447284966_d6bbdb4b6e.jpg  2549968784_39bfbe44f9.jpg#2
# 4     2621415349_ef1a7e73be.jpg  2549968784_39bfbe44f9.jpg#2
# 6     3155451946_c0862c70cb.jpg  2549968784_39bfbe44f9.jpg#2
# ...                         ...                          ...
# 5817   757046028_ff5999f91b.jpg  2061144717_5b3a1864f0.jpg#2
# 5818   799486353_f665d7b0f0.jpg  2196107384_361d73a170.jpg#2
# 5819   909808296_23c427022d.jpg  2112921744_92bf706805.jpg#2
# 5820   929679367_ff8c7df2ee.jpg  3651971126_309e6a5e22.jpg#2
# 5821   968081289_cdba83ce2e.jpg  2292406847_f366350600.jpg#2
#
#                                              query_text
# 0     A young child is wearing blue goggles and sitt...
# 1     A young child is wearing blue goggles and sitt...
# 2     A young child is wearing blue goggles and sitt...
# ...

# %%
# Преобразование текстовых данных в TF-IDF векторы
vectorizer = TfidfVectorizer(max_features=5000)
text_vectors = vectorizer.fit_transform(df_train_filtered['query_text'])

# %%
# Загрузка предобученной модели ResNet50 и удаление последнего слоя
model = resnet50(pretrained=True)
model = torch.nn.Sequential(*list(model.children())[:-1])
# Out:
# C:\Users\Пользователь\AppData\Roaming\Python\Python39\site-packages\torchvision\models\_utils.py:208: UserWarning: The parameter 'pretrained' is deprecated since 0.13 and may be removed in the future, please use 'weights' instead.
#   warnings.warn(
# C:\Users\Пользователь\AppData\Roaming\Python\Python39\site-packages\torchvision\models\_utils.py:223: UserWarning: Arguments other than a weight enum or `None` for 'weights' are deprecated since 0.13 and may be removed in the future. The current behavior is equivalent to passing `weights=ResNet50_Weights.IMAGENET1K_V1`. You can also use `weights=ResNet50_Weights.DEFAULT` to get the most up-to-date weights.
#   warnings.warn(msg)

# %%
# Преобразования для изображений
preprocess = transforms.Compose([
    transforms.Resize(256),
    transforms.CenterCrop(224),
    transforms.ToTensor(),
    transforms.Normalize(mean=[0.485, 0.456, 0.406], std=[0.229, 0.224, 0.225]),
])

# %%
def preprocess_image(img_path):
    img = Image.open(img_path).convert('RGB')
    img_tensor = preprocess(img)
    img_tensor = img_tensor.unsqueeze(0)
    return img_tensor

# %%
def get_image_vector(model, img_path):
    img_tensor = preprocess_image(img_path)
    with torch.no_grad():
        img_vector = model(img_tensor)
    return img_vector.flatten().numpy()

# %%
# Получение векторов для изображений из обучающего набора данных
image_vectors = np.array([get_image_vector(model, Path(path_to_data) / 'train_images' / img) for img in df_train_filtered['image']])

# %%
# Проверка размеров массивов
assert text_vectors.shape[0] == image_vectors.shape[0], "Количество строк в text_vectors и image_vectors должно совпадать"

# %%
# Конкатенация текстовых и изображенческих векторов
combined_vectors = np.hstack((text_vectors.toarray(), image_vectors))

# %%
# Приведение оценки соответствия к диапазону 0-1
df_expert['expert_score'] = df_expert[['first', 'second', 'third']].mean(axis=1) / 3

# %%
# Первое разделение на временные обучающую и валидационную+тестовую выборки
gss = GroupShuffleSplit(n_splits=1, test_size=0.4, random_state=42)
groups = df_train_filtered['image']
train_idx, temp_idx = next(gss.split(combined_vectors, groups=groups))

X_train, X_temp = combined_vectors[train_idx], combined_vectors[temp_idx]
y_train, y_temp = df_expert['expert_score'].iloc[train_idx], df_expert['expert_score'].iloc[temp_idx]

# Второе разделение временной валидационной+тестовой выборки на валидационную и тестовую выборки
gss = GroupShuffleSplit(n_splits=1, test_size=0.5, random_state=42)
val_idx, test_idx = next(gss.split(X_temp, groups=df_train_filtered['image'].iloc[temp_idx]))

X_val, X_test = X_temp[val_idx], X_temp[test_idx]
y_val, y_test = y_temp.iloc[val_idx], y_temp.iloc[test_idx]

# Проверим размеры выборок
print(f"Размеры выборок: Обучающая - {len(X_train)}, Валидационная - {len(X_val)}, Тестовая - {len(X_test)}")
# Out:
# Размеры выборок: Обучающая - 3096, Валидационная - 1026, Тестовая - 1097

# %%
# Вывод размеров выборок для проверки
print(f"Размеры выборок: Обучающая - {len(X_train)}, Валидационная - {len(X_val)}, Тестовая - {len(X_test)}")
# Out:
# Размеры выборок: Обучающая - 3096, Валидационная - 1026, Тестовая - 1097

# %% [markdown]
# <div class="alert" style="background-color:#ead7f7;color:#8737bf">
#     <font size="3"><b>образец комментария студента</b></font>
#
# Внесено
#
# </div>

# %% [markdown]
# В этом обновленном коде:
# 1. Используется GroupShuffleSplit для разделения данных на обучающую и тестовую выборки, чтобы избежать ситуации, когда одна и та же картинка фигурирует в обеих выборках.
#
# 2. Оценка соответствия приводится к диапазону 0-1 путем деления на 3 (максимальная возможная оценка).

# %% [markdown]
# <img src="https://upload.wikimedia.org/wikipedia/commons/b/ba/Warning_sign_4.0.png" align=left width=44, heigth=33>
# <div class="alert alert-warning">
# Разбиение на обучающую и валидационную выборки произведено. Но что-бы избежать ситуации,когда одна и та же картинка фигурирует в обучении и валидации лучше использовать GroupShuffleSplit (есть в прекоде к проекту)</div>

# %% [markdown]
# <img src="https://upload.wikimedia.org/wikipedia/commons/thumb/8/81/Stop_sign.png/240px-Stop_sign.png" align=left width=35, heigth=35>
# <div class="alert alert-danger">
# В описании к проекту указано, что оценка соответствия должна быть приведена к диапазону 0-1. Похоже ты забыл это сделать. </div>

# %% [markdown]
# <div class="alert" style="background-color:#ead7f7;color:#8737bf">
#     <font size="3"><b>образец комментария студента</b></font>
#
# Внесено
#
# </div>

# %% [markdown]
# ### Шаг 3 Обучите модель

# %% [markdown]
# - Создайте модель, которая покажет близость двух векторов. Модель должна принимать на вход конкатенированный вектор, состоящий из векторов описания и изображений, и предсказывать итоговую оценку экспертов.
#
# - Выберите метрику, по которой вы будете сравнивать точность различных моделей.
#
# - Обучите несколько моделей и подберите их гиперпараметры.
#
# - В качестве моделей обязательно нужно рассмотреть:
#
# 1. Линейную регрессию;
#
# 2. Полносвязные нейронные сети.

# %% [markdown]
# 1. **Обоснование выбора метрики MAE:**
#
#    Выбор метрики для оценки модели зависит от характера задачи и специфики данных. В данном случае мы выбрали Mean Absolute Error (MAE) по следующим причинам:
#
#    - **Интерпретируемость:** MAE представляет собой среднее абсолютное отклонение предсказанных значений от истинных, что делает её легко интерпретируемой и понятной для бизнес-аналитиков и специалистов.
#    - **Робастность к выбросам:** В отличие от Mean Squared Error (MSE), MAE менее чувствительна к выбросам, так как не возводит ошибки в квадрат. Это особенно важно, если в данных могут быть аномальные значения, которые могут сильно повлиять на модель при использовании MSE.
#    - **Соответствие задаче:** В данной задаче оценки соответствия изображений и текстов важна точность предсказания средней ошибки, а не её квадрат. MAE позволяет оценить среднюю ошибку в тех же единицах, что и целевая переменная, что упрощает интерпретацию результатов.

# %% [markdown]
# <img src="https://upload.wikimedia.org/wikipedia/commons/b/ba/Warning_sign_4.0.png" align=left width=44, heigth=33>
# <div class="alert alert-warning">
# Похоже импорты дублируются?</div>

# %% [markdown]
# <div class="alert" style="background-color:#ead7f7;color:#8737bf">
#     <font size="3"><b>образец комментария студента</b></font>
#
# Внесено
#
# </div>

# %% [markdown]
# <img src="https://upload.wikimedia.org/wikipedia/commons/thumb/8/81/Stop_sign.png/240px-Stop_sign.png" align=left width=35, heigth=35>
# <div class="alert alert-danger">
# В этом задании требуется выбрать основную метрику, которую ты будешь оптимизировать. Я вижу что ты уже выбрал метрику mae, поэтому просто напиши обоснование для своего выбора.  </div>

# %% [markdown]
# 2. **Регуляризация для борьбы с переобучением:**
#
#    Для борьбы с переобучением в линейной регрессии и нейронных сетях можно использовать различные методы регуляризации.
#
#    **Линейные модели с регуляризацией:**
#
#    - **Ridge Regression (L2-регуляризация):** Добавляет штраф за величину коэффициентов, что помогает уменьшить их значения и уменьшить переобучение.
#    - **Lasso Regression (L1-регуляризация):** Добавляет штраф за абсолютное значение коэффициентов, что может привести к обнулению некоторых из них, тем самым выполняя отбор признаков.

# %%
# Ridge Regression (L2-регуляризация)
ridge_model = Ridge(alpha=1.0)
ridge_model.fit(X_train, y_train)

# Проверка на валидационной выборке
y_val_pred_ridge = ridge_model.predict(X_val)
mae_val_ridge = mean_absolute_error(y_val, y_val_pred_ridge)
print(f"MAE на валидационной выборке для Ridge регрессии: {mae_val_ridge}")
# Out:
# MAE на валидационной выборке для Ridge регрессии: 0.2155446645741864

# %%
# Lasso Regression (L1-регуляризация)
lasso_model = Lasso(alpha=0.1)
lasso_model.fit(X_train, y_train)

# Проверка на валидационной выборке
y_val_pred_lasso = lasso_model.predict(X_val)
mae_val_lasso = mean_absolute_error(y_val, y_val_pred_lasso)
print(f"MAE на валидационной выборке для Lasso регрессии: {mae_val_lasso}")
# Out:
# MAE на валидационной выборке для Lasso регрессии: 0.21420339336873784

# %%
# Создание модели нейронной сети
def create_nn_model(input_dim):
    model = Sequential()
    model.add(Dense(64, input_dim=input_dim, activation='relu', kernel_regularizer='l2'))
    model.add(Dropout(0.5))
    model.add(Dense(32, activation='relu', kernel_regularizer='l2'))
    model.add(Dropout(0.5))
    model.add(Dense(1, activation='linear'))
       
    model.compile(optimizer=Adam(learning_rate=0.001), loss='mean_absolute_error')
    return model

# %%
input_dim = X_train.shape[1]
nn_model = create_nn_model(input_dim)
# Out:
# C:\Users\Пользователь\AppData\Roaming\Python\Python39\site-packages\keras\src\layers\core\dense.py:87: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)

# %%
# Обучение модели нейронной сети на обучающей выборке
nn_model.fit(X_train, y_train, epochs=50, batch_size=32, validation_data=(X_val, y_val), verbose=1)
# Out:
# Epoch 1/50
# 97/97 ━━━━━━━━━━━━━━━━━━━━ 3s 12ms/step - loss: 1.4703 - val_loss: 0.6032
# Epoch 2/50
# 97/97 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - loss: 0.5379 - val_loss: 0.3709
# Epoch 3/50
# 97/97 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - loss: 0.3545 - val_loss: 0.2835
# Epoch 4/50
# 97/97 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - loss: 0.2789 - val_loss: 0.2440
# Epoch 5/50
# 97/97 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - loss: 0.2440 - val_loss: 0.2279
# Epoch 6/50
# 97/97 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - loss: 0.2318 - val_loss: 0.2169
# Epoch 7/50
# 97/97 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - loss: 0.2161 - val_loss: 0.2131
# Epoch 8/50
# 97/97 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - loss: 0.2196 - val_loss: 0.2072
# Epoch 9/50
# 97/97 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - loss: 0.2106 - val_loss: 0.2081
# Epoch 10/50
# 97/97 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - loss: 0.2151 - val_loss: 0.2037
# Epoch 11/50
# 97/97 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - loss: 0.2085 - val_loss: 0.2026
# Epoch 12/50
# ...

# %%
# Предсказание на валидационной выборке
y_val_pred_nn = nn_model.predict(X_val).flatten()
# Out:
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step

# %%
# Оценка модели на валидационной выборке
mae_val_nn = mean_absolute_error(y_val, y_val_pred_nn)
print(f"MAE на валидационной выборке для полносвязной нейронной сети с регуляризацией: {mae_val_nn}")
# Out:
# MAE на валидационной выборке для полносвязной нейронной сети с регуляризацией: 0.19888294596472728

# %% [markdown]
# ### 1. Изменение архитектуры сети
# Изменено количество слоев и количество нейронов в каждом слое.

# %%
from sklearn.model_selection import GroupShuffleSplit, GridSearchCV
from sklearn.pipeline import Pipeline
from sklearn.preprocessing import StandardScaler
from sklearn.base import BaseEstimator, RegressorMixin
from keras.models import Sequential
from keras.layers import Dense, Dropout
from keras.optimizers import Adam

# %%
# Проверим размеры выборок
print(f"Размеры выборок: Обучающая - {len(X_train)}, Валидационная - {len(X_val)}, Тестовая - {len(X_test)}")
# Out:
# Размеры выборок: Обучающая - 3096, Валидационная - 1026, Тестовая - 1097

# %%
# Нормализация данных
scaler = StandardScaler()
X_train_scaled = scaler.fit_transform(X_train)
X_test_scaled = scaler.transform(X_test)

# %%
# Функция для создания модели
def create_model(input_dim, neurons=32, dropout_rate=0.3, learning_rate=0.001):
    model = Sequential()
    model.add(Dense(neurons, input_dim=input_dim, activation='relu'))
    model.add(Dropout(dropout_rate))
    model.add(Dense(1))
    
    optimizer = Adam(learning_rate=learning_rate)
    model.compile(optimizer=optimizer, loss='mean_absolute_error', metrics=['mae'])
    return model

# %%
from sklearn.metrics import make_scorer, mean_absolute_error

# Гиперпараметры для перебора
param_grid = {
    'neurons': [32, 64, 128],
    'dropout_rate': [0.2, 0.3, 0.4],
    'learning_rate': [0.001, 0.01],
    'batch_size': [16, 32],
    'epochs': [50, 100]
}

best_mae = float('inf')
best_params = {}
best_model = None

# Перебор гиперпараметров
for neurons in param_grid['neurons']:
    for dropout_rate in param_grid['dropout_rate']:
        for learning_rate in param_grid['learning_rate']:
            for batch_size in param_grid['batch_size']:
                for epochs in param_grid['epochs']:
                    print(f"Training model with neurons={neurons}, dropout_rate={dropout_rate}, learning_rate={learning_rate}, batch_size={batch_size}, epochs={epochs}")
# Out:
# Training model with neurons=32, dropout_rate=0.2, learning_rate=0.001, batch_size=16, epochs=50
# Training model with neurons=32, dropout_rate=0.2, learning_rate=0.001, batch_size=16, epochs=100
# Training model with neurons=32, dropout_rate=0.2, learning_rate=0.001, batch_size=32, epochs=50
# Training model with neurons=32, dropout_rate=0.2, learning_rate=0.001, batch_size=32, epochs=100
# Training model with neurons=32, dropout_rate=0.2, learning_rate=0.01, batch_size=16, epochs=50
# Training model with neurons=32, dropout_rate=0.2, learning_rate=0.01, batch_size=16, epochs=100
# Training model with neurons=32, dropout_rate=0.2, learning_rate=0.01, batch_size=32, epochs=50
# Training model with neurons=32, dropout_rate=0.2, learning_rate=0.01, batch_size=32, epochs=100
# Training model with neurons=32, dropout_rate=0.3, learning_rate=0.001, batch_size=16, epochs=50
# Training model with neurons=32, dropout_rate=0.3, learning_rate=0.001, batch_size=16, epochs=100
# ...

# %%
# Создание модели
model = create_model(input_dim=X_train_scaled.shape[1], neurons=neurons, dropout_rate=dropout_rate, learning_rate=learning_rate)
# Out:
# C:\Users\Пользователь\AppData\Roaming\Python\Python39\site-packages\keras\src\layers\core\dense.py:87: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)

# %%
# Ранняя остановка
early_stopping = EarlyStopping(monitor='val_loss', patience=10, restore_best_weights=True)

# %%
history = model.fit(X_train_scaled, y_train,
                                        validation_split=0.2,
                                        epochs=epochs,
                                        batch_size=batch_size,
                                        callbacks=[early_stopping],
                                        verbose=0)

# %%
# Оценка модели на валидационной выборке
val_mae = min(history.history['val_mae'])
print(f"Validation MAE: {val_mae}")
# Out:
# Validation MAE: 0.7808930277824402

# %%
if val_mae < best_mae:
    best_mae = val_mae
    best_params = {
        'neurons': neurons,
        'dropout_rate': dropout_rate,
        'learning_rate': learning_rate,
        'batch_size': batch_size,
        'epochs': epochs
    }
    best_model = model

# %%
print(f"Best parameters: {best_params}")
print(f"Best validation MAE: {best_mae}")
# Out:
# Best parameters: {'neurons': 128, 'dropout_rate': 0.4, 'learning_rate': 0.01, 'batch_size': 32, 'epochs': 100}
# Best validation MAE: 0.7808930277824402

# %%
y_pred = best_model.predict(X_test_scaled)

plt.figure(figsize=(10, 5))
plt.scatter(y_test, y_pred)
plt.plot([min(y_test), max(y_test)], [min(y_test), max(y_test)], 'r--')
plt.xlabel('True Values')
plt.ylabel('Predicted Values')
plt.title('True vs Predicted Values')
plt.show()
# Out:
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step

# %% [markdown]
# ### Шаг 4. Тестирование модели и демонстрация ее работы

# %% [markdown]
# - Проведите тестирование лучшей модели на тестовых данных.
#
# - Напишите функцию, которая принимает на вход текстовое описание, делает его векторизацию и возвращает картинку с максимальным значением метрики.

# %%
# Оценка лучшей модели на тестовой выборке
test_mae = mean_absolute_error(y_test, best_model.predict(X_test_scaled))
print(f"Test MAE: {test_mae}")
# Out:
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# Test MAE: 0.5884677081693453

# %%
# Визуализация результатов
#results_sorted = sorted(results, key=lambda x: x[-1])
#mae_values = [result[-1] for result in results_sorted]

# Построение графика
plt.figure(figsize=(10, 6))
plt.plot(y_test.values, label='Реальные значения', marker='o')
plt.plot(y_pred, label='Предсказанные значения', marker='x')
plt.xlabel('Примеры')
plt.ylabel('Значения')
plt.title('Сравнение реальных и предсказанных значений на тестовой выборке')
plt.legend()
plt.show()

# %% [markdown]
# <img src="https://upload.wikimedia.org/wikipedia/commons/b/ba/Warning_sign_4.0.png" align=left width=44, heigth=33>
# <div class="alert alert-warning">
# Совершенно непонятно зачем ты обучаешь две абсолютно одинаковых архитектуры используя разные фреймворки... Лучше взять какой-то один фреймворк, но поработаь с архитектурой/гиперпараметрами обучения.
#
# </div>

# %% [markdown]
# <img src="https://upload.wikimedia.org/wikipedia/commons/thumb/8/81/Stop_sign.png/240px-Stop_sign.png" align=left width=35, heigth=35>
# <div class="alert alert-danger">
# Совершенно непонятно что происходит в этой ячейке. Во первых, зачем дублировать такие большие функции. Во вторых, похоже ты выводишь тестовые изображения? Но лучше сделать это на этапе знакомства с данными. А здесь наша цель простая - реализовать тестирование модели.
# .</div>

# %% [markdown]
# <div class="alert" style="background-color:#ead7f7;color:#8737bf">
#     <font size="3"><b>образец комментария студента</b></font>
#
# Внесено
#
# </div>

# %%
# Функция для получения списка всех изображений в папке
def get_image_paths_from_folder(folder_path):
    image_paths = []
    for root, dirs, files in os.walk(folder_path):
        for file in files:
            if file.lower().endswith(('.png', '.jpg', '.jpeg', '.bmp', '.gif')):
                image_paths.append(os.path.join(root, file))
    return image_paths

# Пример функции векторизации текста (замените на вашу реализацию)
def vectorize_text(text, vectorizer):
    # Ваша логика для векторизации текста
    return vectorizer.transform([text])

# Пример функции для получения метрики близости (замените на вашу реализацию)
def predict_similarity(text_vector, image_vectors, model):
    # Ваша логика для предсказания метрики близости
    similarities = model.predict_proba([text_vector] * len(image_vectors), image_vectors)
    return similarities

# Основная функция для получения лучшего изображения
def get_best_image_with_metric(text_description, model, vectorizer, image_df):
    if not text_description:
        return "Некорректный запрос: текстовое описание не должно быть пустым.", None
    
    try:
        # Векторизация текстового описания
        text_vector = vectorize_text(text_description, vectorizer)
        
        # Получение заранее подготовленных векторов изображений
        image_vectors = image_df['image_vector'].tolist()
        
        # Предсказание метрик близости
        similarities = predict_similarity(text_vector, image_vectors, model)
        
        # Добавление метрик в DataFrame
        image_df['similarity'] = similarities
        
        # Сортировка по метрике и выбор лучшего изображения
        best_image_row = image_df.sort_values(by='similarity', ascending=False).iloc[0]
        best_image_path = best_image_row['image_path']
        best_similarity = best_image_row['similarity']
        
        return best_image_path, best_similarity
    
    except Exception as e:
        return f"Произошла ошибка: {e}", None

# %%
text_description_example = "dog"
model = best_model  
vectorizer = text_vectors  

# Путь к папке с изображениями (замените на ваш путь)
folder_path = 'C:\\datasets\\image_search\\to_upload\\test_images'

# Получаем все пути к изображениям в папке
image_paths = get_image_paths_from_folder(folder_path)

# Создаем DataFrame с путями к изображениям и добавляем заранее подготовленные векторы изображений
image_vectors = [get_image_vector(path) for path in image_paths]  
image_df = pd.DataFrame({'image_path': image_paths, 'image_vector': image_vectors})

# %%
best_image_example, similarity_metric = get_best_image_with_metric(text_description_example, model, vectorizer, image_df)
print("Лучшее изображение для данного текста:")

if best_image_example and os.path.exists(best_image_example):
    try:
        img = Image.open(best_image_example)
        img.show()  
        print(f"Метрика близости: {similarity_metric}")
    except Exception as e:
        print(f"Произошла ошибка при открытии изображения: {e}")
else:
    print(f"Изображение по пути {best_image_example} не найдено.")

# %% [markdown]
# # Функция для получения списка всех изображений в папке
# def get_image_paths_from_folder(folder_path):
#     image_paths = []
#     for root, dirs, files in os.walk(folder_path):
#         for file in files:
#             if file.lower().endswith(('.png', '.jpg', '.jpeg', '.bmp', '.gif')):
#                 image_paths.append(os.path.join(root, file))
#     return image_paths
#
# # Пример функции get_best_image (замените на вашу реализацию)
# def get_best_image(text_description, model, vectorizer, image_df):
#     # Ваша логика для выбора лучшего изображения
#     # Здесь просто возвращается первый путь как пример
#     return image_df['image_path'].iloc[0]
#
# # Пример использования функции get_best_image
# text_description_example = "dog"  # Замените на ваше текстовое описание
# model = best_model  # Замените на вашу модель
# vectorizer = text_vectors  # Замените на ваш векторизатор
#
# # Путь к папке с изображениями (замените на ваш путь)
# folder_path = 'C:\\datasets\\image_search\\to_upload\\test_images'
#
# # Получаем все пути к изображениям в папке
# image_paths = get_image_paths_from_folder(folder_path)
#
# # Создаем DataFrame с путями к изображениям
# image_df = pd.DataFrame({'image_path': image_paths})
#
# # Получаем лучшее изображение
# best_image_example = get_best_image(text_description_example, model, vectorizer, image_df)
# print("Лучшее изображение для данного текста:")
#
# if os.path.exists(best_image_example):
#     try:
#         img = Image.open(best_image_example)
#         img.show()  # Отображение изображения с использованием PIL
#     except Exception as e:
#         print(f"Произошла ошибка при открытии изображения: {e}")
# else:
#     print(f"Изображение по пути {best_image_example} не найдено.")

# %% [markdown]
# <img src="https://upload.wikimedia.org/wikipedia/commons/thumb/8/81/Stop_sign.png/240px-Stop_sign.png" align=left width=35, heigth=35>
# <div class="alert alert-danger">
# Похоже здесь ты не закончил свою работу.  Поэтому просто напишу свое видение как должна работать функция для поискаизображений по запросу.
#
#
# Что должна делаь функция
#
#    - Получать текст
#    - Возвращать картинку и метрику близости.
#    - Выдавать дисклеймер если запрос некорректный
#
# Под капотом функция должна векторизовать полученный текст, и с помощью модели получить предсказание для 100 пар (вектор описания + вектор изображения), где вектор описания мы получили только что, а 100 векторов изображений получили заранее.
#
# И дальше ищем изображение, для которого модель покажет максимальную метрику.
#
#
#
# ---
#
#  А затем нужно 10 раз применить функцию к 10 случайным запросам.
#
# И не пугайся, если вдруг ты увидишь, что качества угадывания модели  близкое к рандомному угадыванию. К сожалению такое случается, но зато мы будем четко понимать, что функции для инференса работают корректно,  а вот модель "подкачала".
#
# .</div>

# %% [markdown]
# <div class="alert" style="background-color:#ead7f7;color:#8737bf">
#     <font size="3"><b>образец комментария студента</b></font>
#
# Внесено
#
# </div>
